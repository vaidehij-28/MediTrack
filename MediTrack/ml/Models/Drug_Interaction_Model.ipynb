# %% [markdown]
# # Drug Interaction Prediction Model
#
# ## Algorithm: Random Forest Classifier
# ## Data: 379 interactions
# ## Target: severity_level (High/Medium/Low)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f630d5e0-192e-4722-881c-437fdcf1ae58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f630d5e0-192e-4722-881c-437fdcf1ae58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load data
interactions = pd.read_csv('interaction_clean.csv')
print(f"Interactions: {len(interactions)}")
print(interactions['severity_level'].value_counts())
# Out:
# Interactions: 379
# severity_level
# High          279
# Medium         81
# Low            15
# Low/Medium      4
# Name: count, dtype: int64

# %%
# Prepare features
interactions['text_features'] = interactions['drug1'] + ' ' + interactions['drug2'] + ' ' + interactions['description'].fillna('')

# TF-IDF
tfidf = TfidfVectorizer(max_features=1000, stop_words='english')
X_text = tfidf.fit_transform(interactions['text_features'])

# Label encoding
le = LabelEncoder()
y = le.fit_transform(interactions['severity_level'])

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_text, y, test_size=0.2, random_state=42)

# Train model
rf_interaction = RandomForestClassifier(n_estimators=100, random_state=42)
rf_interaction.fit(X_train, y_train)

# Evaluate
y_pred = rf_interaction.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Save model
pickle.dump(rf_interaction, open('interaction_model.pkl', 'wb'))
pickle.dump(tfidf, open('interaction_tfidf.pkl', 'wb'))
pickle.dump(le, open('interaction_label_encoder.pkl', 'wb'))
print("Model saved!")
# Out:
# Accuracy: 0.974
#               precision    recall  f1-score   support
#
#         High       0.96      1.00      0.98        55
#          Low       1.00      1.00      1.00         2
#   Low/Medium       1.00      1.00      1.00         1
#       Medium       1.00      0.89      0.94        18
#
#     accuracy                           0.97        76
#    macro avg       0.99      0.97      0.98        76
# weighted avg       0.97      0.97      0.97        76
#
# Model saved!

# %%
from google.colab import files
files.download('interaction_model.pkl')
files.download('interaction_tfidf.pkl')
files.download('interaction_label_encoder.pkl')
print("Drug Interaction model downloaded!")
# Out:
# Drug Interaction model downloaded!
